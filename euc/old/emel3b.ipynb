# %%
emel3b = read.delim("emel3b.tab")

# %%
summary(emel3b)
# Out:
#      Locus               Size             NumTags       ModeSizeNumTags
#  Min.   :   14061   Min.   :       2   Min.   :   2.0   Min.   :   2.0
#  1st Qu.: 8155702   1st Qu.:      66   1st Qu.:   3.0   1st Qu.:   3.0
#  Median :16335571   Median :     130   Median :   8.0   Median :   7.0
#  Mean   :17754482   Mean   :  146002   Mean   : 175.6   Mean   : 167.9
#  3rd Qu.:28230106   3rd Qu.:     235   3rd Qu.:  49.0   3rd Qu.:  45.0
#  Max.   :35334934   Max.   :35408378   Max.   :6985.0   Max.   :6920.0

# %%
emel3b = subset(emel3b, Size < 500)

# %%
hist(emel3b$Size, breaks=100)
# Out:
# Plot with title “Histogram of emel3b$Size”

# %%
plot(emel3b$Size, emel3b$NumTags)
# Out:
# plot without title

# %%
plot(emel3b$Size, emel3b$NumTags, ylim=c(0, 500))
# Out:
# plot without title

# %%
table(emel3b$NumTags > 500)
# Out:
# FALSE  TRUE
#  2468   248
